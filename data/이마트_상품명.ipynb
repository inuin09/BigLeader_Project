# %% [markdown]
# <a href="https://colab.research.google.com/github/inuin09/BigLeader_Project/blob/main/%EC%9D%B4%EB%A7%88%ED%8A%B8_%EC%83%81%ED%92%88%EB%AA%85.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
train_df = pd.read_csv('/content/sample_data/양파_이마트_이름.csv')
train_df
# Out:
# Empty DataFrame
# Columns: [
#
# [푸릇] 무농약 친환경 햇 양파 1kg
# [푸릇] 무농약 친환경 햇 양파 1kg
# [푸릇] 무농약 친환경 햇 양파 1kg
#
# ,
#
# [푸릇] 무농약 친환경 햇 양파 1.5kg(기획용)
# [푸릇] 무농약 친환경 햇 양파 1.5kg(기획용)
# [푸릇] 무농약 친환경 햇 양파 1.5kg(기획용)
#
# ,
#
# SSG.Fresh
# SSG.Fresh
#
#
# 수제망 양파 1.8Kg내외 (망)
# 수제망 양파 1.8Kg내외 (망)
# 수제망 양파 1.8Kg내외 (망)
#
# ,
#
# 친환경 깐양파 300g
# 친환경 깐양파 300g
# 친환경 깐양파 300g
#
# ,
#
# 무농약 친환경 양파 1kg/망
# 무농약 친환경 양파 1kg/망
# 무농약 친환경 양파 1kg/망
#
# ,
#
# SSG.Fresh
# SSG.Fresh
#
#
# 양파 용기는 재생 플라스틱을 활용한 용기 입니다. / 해당 상품은 깐 양파가 아닌 껍질이 있는 양파 입니다. 구매에 참고 부탁드립니다. 속이 보이는 양파 4입(팩)
# 속이 보이는 양파 4입(팩)
# 속이 보이는 양파 4입(팩)
#
# ,
#
# SSG.Fresh
# SSG.Fresh
#
#
# 장아찌용 양파 3Kg내외(망)
# 장아찌용 양파 3Kg내외(망)
# 장아찌용 양파 3Kg내외(망)
#
# ,
#
# SSG FOOD MARKET
# SSG FOOD MARKET
#
#
# SSG 양파 5입 (1.25kg)
# SSG 양파 5입 (1.25kg)
# SSG 양파 5입 (1.25kg)
#
# ,
#
# SSG FOOD MARKET
# SSG FOOD MARKET
#
#
# 친환경 깐양파 2입(400g내외)
# 친환경 깐양파 2입(400g내외)
# 친환경 깐양파 2입(400g내외)
#
# ,
#
# SSG 창립기획 친환경 인기상품 특가
# SSG 창립기획 친환경 인기상품 특가
# SSG 창립기획 친환경 인기상품 특가
#
# ,
#
# ...

# %%
train_df=train_df.transpose()
train_df
# Out:
# Empty DataFrame
# Columns: []
# Index: [
#
# [푸릇] 무농약 친환경 햇 양파 1kg
# [푸릇] 무농약 친환경 햇 양파 1kg
# [푸릇] 무농약 친환경 햇 양파 1kg
#
# ,
#
# [푸릇] 무농약 친환경 햇 양파 1.5kg(기획용)
# [푸릇] 무농약 친환경 햇 양파 1.5kg(기획용)
# [푸릇] 무농약 친환경 햇 양파 1.5kg(기획용)
#
# ,
#
# SSG.Fresh
# SSG.Fresh
#
#
# 수제망 양파 1.8Kg내외 (망)
# 수제망 양파 1.8Kg내외 (망)
# 수제망 양파 1.8Kg내외 (망)
#
# ,
#
# 친환경 깐양파 300g
# 친환경 깐양파 300g
# 친환경 깐양파 300g
#
# ,
#
# 무농약 친환경 양파 1kg/망
# 무농약 친환경 양파 1kg/망
# 무농약 친환경 양파 1kg/망
#
# ,
#
# SSG.Fresh
# SSG.Fresh
#
#
# 양파 용기는 재생 플라스틱을 활용한 용기 입니다. / 해당 상품은 깐 양파가 아닌 껍질이 있는 양파 입니다. 구매에 참고 부탁드립니다. 속이 보이는 양파 4입(팩)
# 속이 보이는 양파 4입(팩)
# 속이 보이는 양파 4입(팩)
#
# ,
#
# SSG.Fresh
# SSG.Fresh
#
#
# 장아찌용 양파 3Kg내외(망)
# 장아찌용 양파 3Kg내외(망)
# 장아찌용 양파 3Kg내외(망)
#
# ,
#
# SSG FOOD MARKET
# SSG FOOD MARKET
#
#
# SSG 양파 5입 (1.25kg)
# SSG 양파 5입 (1.25kg)
# SSG 양파 5입 (1.25kg)
#
# ,
#
# SSG FOOD MARKET
# SSG FOOD MARKET
#
#
# 친환경 깐양파 2입(400g내외)
# 친환경 깐양파 2입(400g내외)
# 친환경 깐양파 2입(400g내외)
#
# ,
#
# SSG 창립기획 친환경 인기상품 특가
# SSG 창립기획 친환경 인기상품 특가
# SSG 창립기획 친환경 인기상품 특가
#
# ,
# ...

# %%
train_df.to_csv('이마트_양파_준전처리.csv',mode='w',encoding='utf-8-sig')

# %%
train_df = pd.read_csv('/content/sample_data/이마트_양파_준전처리.csv')
train_df
# Out:
#                                                    제품명
# 0    \r\n\r\n[푸릇] 무농약 친환경 햇 양파 1kg\r\n[푸릇] 무농약 친환경 ...
# 1    \r\n\r\n[푸릇] 무농약 친환경 햇 양파 1.5kg(기획용)\r\n[푸릇] 무...
# 2    \r\n\r\nSSG.Fresh\r\nSSG.Fresh\r\n\r\n\r\n수제망 ...
# 3    \r\n\r\n친환경 깐양파 300g\r\n친환경 깐양파 300g\r\n친환경 깐양...
# 4    \r\n\r\n무농약 친환경 양파 1kg/망\r\n무농약 친환경 양파 1kg/망\r...
# ..                                                 ...
# 235  \r\n\r\n다온푸드\r\n다온푸드\r\n\r\n\r\n[신선팜]국내산 적 양파 ...
# 236  \r\n\r\n아이홈푸드\r\n아이홈푸드\r\n\r\n\r\n(산지직송) 햇 무안자...
# 237  \r\n\r\n아이홈푸드\r\n아이홈푸드\r\n\r\n\r\n(산지직송) 햇 무안자...
# 238  \r\n\r\n자연맛남\r\n자연맛남\r\n\r\n\r\n 아삭한 황토 햇 자색양파...
# 239  \r\n\r\n오창농협\r\n오창농협\r\n\r\n\r\n 무농약 양파 2입\r\n...
#
# [240 rows x 1 columns]

# %%
train_df = train_df.replace('\n','',regex=True)
train_df
# Out:
#                                                    제품명
# 0    \r\r[푸릇] 무농약 친환경 햇 양파 1kg\r[푸릇] 무농약 친환경 햇 양파 1...
# 1    \r\r[푸릇] 무농약 친환경 햇 양파 1.5kg(기획용)\r[푸릇] 무농약 친환경...
# 2    \r\rSSG.Fresh\rSSG.Fresh\r\r\r수제망 양파 1.8Kg내외 (...
# 3     \r\r친환경 깐양파 300g\r친환경 깐양파 300g\r친환경 깐양파 300g\r\r
# 4    \r\r무농약 친환경 양파 1kg/망\r무농약 친환경 양파 1kg/망\r무농약 친환...
# ..                                                 ...
# 235  \r\r다온푸드\r다온푸드\r\r\r[신선팜]국내산 적 양파 10kg\r[신선팜]국...
# 236  \r\r아이홈푸드\r아이홈푸드\r\r\r(산지직송) 햇 무안자색양파 5kg / 소\...
# 237  \r\r아이홈푸드\r아이홈푸드\r\r\r(산지직송) 햇 무안자색양파 10kg / 대...
# 238  \r\r자연맛남\r자연맛남\r\r\r 아삭한 황토 햇 자색양파 10kg (특대)\r...
# 239  \r\r오창농협\r오창농협\r\r\r 무농약 양파 2입\r무농약 양파 2입\r무농약...
#
# [240 rows x 1 columns]

# %%
train_df = train_df.replace('\r','',regex=True)
train_df
# Out:
#                                                    제품명
# 0    [푸릇] 무농약 친환경 햇 양파 1kg[푸릇] 무농약 친환경 햇 양파 1kg[푸릇]...
# 1    [푸릇] 무농약 친환경 햇 양파 1.5kg(기획용)[푸릇] 무농약 친환경 햇 양파 ...
# 2    SSG.FreshSSG.Fresh수제망 양파 1.8Kg내외 (망)수제망 양파 1.8...
# 3                 친환경 깐양파 300g친환경 깐양파 300g친환경 깐양파 300g
# 4     무농약 친환경 양파 1kg/망무농약 친환경 양파 1kg/망무농약 친환경 양파 1kg/망
# ..                                                 ...
# 235  다온푸드다온푸드[신선팜]국내산 적 양파 10kg[신선팜]국내산 적 양파 10kg[신...
# 236  아이홈푸드아이홈푸드(산지직송) 햇 무안자색양파 5kg / 소(산지직송) 햇 무안자색...
# 237  아이홈푸드아이홈푸드(산지직송) 햇 무안자색양파 10kg / 대(산지직송) 햇 무안자...
# 238  자연맛남자연맛남 아삭한 황토 햇 자색양파 10kg (특대)아삭한 황토 햇 자색양파 ...
# 239               오창농협오창농협 무농약 양파 2입무농약 양파 2입무농약 양파 2입
#
# [240 rows x 1 columns]

# %%
#인덱스 초기화
train_df = train_df.reset_index(drop=True)
train_df
# Out:
#                                                    제품명
# 0    [푸릇] 무농약 친환경 햇 양파 1kg[푸릇] 무농약 친환경 햇 양파 1kg[푸릇]...
# 1    [푸릇] 무농약 친환경 햇 양파 1.5kg(기획용)[푸릇] 무농약 친환경 햇 양파 ...
# 2    SSG.FreshSSG.Fresh수제망 양파 1.8Kg내외 (망)수제망 양파 1.8...
# 3                 친환경 깐양파 300g친환경 깐양파 300g친환경 깐양파 300g
# 4     무농약 친환경 양파 1kg/망무농약 친환경 양파 1kg/망무농약 친환경 양파 1kg/망
# ..                                                 ...
# 235  다온푸드다온푸드[신선팜]국내산 적 양파 10kg[신선팜]국내산 적 양파 10kg[신...
# 236  아이홈푸드아이홈푸드(산지직송) 햇 무안자색양파 5kg / 소(산지직송) 햇 무안자색...
# 237  아이홈푸드아이홈푸드(산지직송) 햇 무안자색양파 10kg / 대(산지직송) 햇 무안자...
# 238  자연맛남자연맛남 아삭한 황토 햇 자색양파 10kg (특대)아삭한 황토 햇 자색양파 ...
# 239               오창농협오창농협 무농약 양파 2입무농약 양파 2입무농약 양파 2입
#
# [240 rows x 1 columns]

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240 entries, 0 to 239
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   제품명     240 non-null    object
# dtypes: object(1)
# memory usage: 2.0+ KB

# %%
#자색 양파 제거

# %%
train_df = train_df[~train_df['제품명'].str.contains("자색양파",na=False, case=False)]
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 199 entries, 0 to 239
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   제품명     199 non-null    object
# dtypes: object(1)
# memory usage: 3.1+ KB

# %%
train_df
# Out:
#                                                    제품명
# 0    [푸릇] 무농약 친환경 햇 양파 1kg[푸릇] 무농약 친환경 햇 양파 1kg[푸릇]...
# 1    [푸릇] 무농약 친환경 햇 양파 1.5kg(기획용)[푸릇] 무농약 친환경 햇 양파 ...
# 2    SSG.FreshSSG.Fresh수제망 양파 1.8Kg내외 (망)수제망 양파 1.8...
# 3                 친환경 깐양파 300g친환경 깐양파 300g친환경 깐양파 300g
# 4     무농약 친환경 양파 1kg/망무농약 친환경 양파 1kg/망무농약 친환경 양파 1kg/망
# ..                                                 ...
# 230  푸르젠푸르젠[함평천지농협] 21년산 양파 10kg(왕 300g 이상)[함평천지농협]...
# 233  맛다름맛다름[가락시장 경매 식자재 채소] 양파(大) 12kg/망[가락시장 경매 식자...
# 234  친환경팔도친환경팔도[팔도농장] 21년 수확 햇 수미감자 5kg+ 햇 무안양파 5kg...
# 235  다온푸드다온푸드[신선팜]국내산 적 양파 10kg[신선팜]국내산 적 양파 10kg[신...
# 239               오창농협오창농협 무농약 양파 2입무농약 양파 2입무농약 양파 2입
#
# [199 rows x 1 columns]

# %%
train_df = train_df[~train_df['제품명'].str.contains("슬라이스",na=False, case=False)]
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 199 entries, 0 to 239
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   제품명     199 non-null    object
# dtypes: object(1)
# memory usage: 3.1+ KB

# %%
train_df.to_csv('이마트_양파1.csv',mode='w',encoding='utf-8-sig')

# %%
train_df = train_df[~train_df['제품명'].str.contains("샬롯",na=False, case=False)]
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 193 entries, 0 to 239
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   제품명     193 non-null    object
# dtypes: object(1)
# memory usage: 3.0+ KB

# %%
train_df = train_df[~train_df['제품명'].str.contains("적양파",na=False, case=False)]
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 182 entries, 0 to 239
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   제품명     182 non-null    object
# dtypes: object(1)
# memory usage: 2.8+ KB

# %%
train_df
# Out:
#                                                    제품명
# 0    [푸릇] 무농약 친환경 햇 양파 1kg[푸릇] 무농약 친환경 햇 양파 1kg[푸릇]...
# 1    [푸릇] 무농약 친환경 햇 양파 1.5kg(기획용)[푸릇] 무농약 친환경 햇 양파 ...
# 2    SSG.FreshSSG.Fresh수제망 양파 1.8Kg내외 (망)수제망 양파 1.8...
# 3                 친환경 깐양파 300g친환경 깐양파 300g친환경 깐양파 300g
# 4     무농약 친환경 양파 1kg/망무농약 친환경 양파 1kg/망무농약 친환경 양파 1kg/망
# ..                                                 ...
# 230  푸르젠푸르젠[함평천지농협] 21년산 양파 10kg(왕 300g 이상)[함평천지농협]...
# 233  맛다름맛다름[가락시장 경매 식자재 채소] 양파(大) 12kg/망[가락시장 경매 식자...
# 234  친환경팔도친환경팔도[팔도농장] 21년 수확 햇 수미감자 5kg+ 햇 무안양파 5kg...
# 235  다온푸드다온푸드[신선팜]국내산 적 양파 10kg[신선팜]국내산 적 양파 10kg[신...
# 239               오창농협오창농협 무농약 양파 2입무농약 양파 2입무농약 양파 2입
#
# [182 rows x 1 columns]

# %%
train_df.to_csv('이마트_양파2.csv',mode='w',encoding='utf-8-sig')

# %% [markdown]
# 장아찌용, 말랭이, 다진양파, 자색 양파, 다져진 양파, 적 양파 제외단계 필요
# 행사제품으로 다양한 채소를 함께 파는 단계는 수작업으로 제거 완료

# %%
train_df = pd.read_csv('/content/sample_data/이마트_양파중간.csv')
train_df
# Out:
#                                                    제품명
# 0    [푸릇] 무농약 친환경 햇 양파 1kg[푸릇] 무농약 친환경 햇 양파 1kg[푸릇]...
# 1    [푸릇] 무농약 친환경 햇 양파 1.5kg(기획용)[푸릇] 무농약 친환경 햇 양파 ...
# 2    SSG.FreshSSG.Fresh수제망 양파 1.8Kg내외 (망)수제망 양파 1.8...
# 3                 친환경 깐양파 300g친환경 깐양파 300g친환경 깐양파 300g
# 4     무농약 친환경 양파 1kg/망무농약 친환경 양파 1kg/망무농약 친환경 양파 1kg/망
# ..                                                 ...
# 155     팸쿡팸쿡가락시장직송 양파 10kg가락시장직송 양파 10kg가락시장직송 양파 10kg
# 156  푸르젠푸르젠[함평천지농협] 21년산 양파 10kg(왕 300g 이상)[함평천지농협]...
# 157  맛다름맛다름[가락시장 경매 식자재 채소] 양파(大) 12kg/망[가락시장 경매 식자...
# 158  다온푸드다온푸드[신선팜]국내산 적 양파 10kg[신선팜]국내산 적 양파 10kg[신...
# 159               오창농협오창농협 무농약 양파 2입무농약 양파 2입무농약 양파 2입
#
# [160 rows x 1 columns]

# %%
train_df = train_df[~train_df['제품명'].str.contains("적 양파",na=False, case=False)]
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 159 entries, 0 to 159
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   제품명     159 non-null    object
# dtypes: object(1)
# memory usage: 2.5+ KB

# %%
train_df = train_df[~train_df['제품명'].str.contains("장아찌용",na=False, case=False)]
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 155 entries, 0 to 159
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   제품명     155 non-null    object
# dtypes: object(1)
# memory usage: 2.4+ KB

# %%
train_df = train_df[~train_df['제품명'].str.contains("다져진",na=False, case=False)]
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 152 entries, 0 to 159
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   제품명     152 non-null    object
# dtypes: object(1)
# memory usage: 2.4+ KB

# %%
train_df = train_df[~train_df['제품명'].str.contains("자색",na=False, case=False)]
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 149 entries, 0 to 159
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   제품명     149 non-null    object
# dtypes: object(1)
# memory usage: 2.3+ KB

# %%
train_df = train_df[~train_df['제품명'].str.contains("다진",na=False, case=False)]
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 148 entries, 0 to 159
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   제품명     148 non-null    object
# dtypes: object(1)
# memory usage: 2.3+ KB

# %%
train_df = train_df[~train_df['제품명'].str.contains("말랭이",na=False, case=False)]
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 147 entries, 0 to 159
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   제품명     147 non-null    object
# dtypes: object(1)
# memory usage: 2.3+ KB

# %%
train_df.to_csv('이마트_양파3.csv',mode='w',encoding='utf-8-sig')
